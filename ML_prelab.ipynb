# %% [markdown]
# <a href="https://colab.research.google.com/github/Omprakashahu/om/blob/main/ML_prelab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Omprakash Shahu (CS23064)
#
# Pre-Lab : Understand Google Colab and Python Libraries for Machine Learning [ Numpy,Panda, Matplotlib,Seaborn,Scikit-learn]

# %%
'Numpy'
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print("NumPy Array:", arr)

arr_plus_one = arr + 1
print("Array + 1:", arr_plus_one)
# Out:
# NumPy Array: [1 2 3 4 5]
# Array + 1: [2 3 4 5 6]
